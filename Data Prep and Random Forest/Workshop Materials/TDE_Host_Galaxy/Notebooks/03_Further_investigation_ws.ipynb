# %% [markdown]
# Author: Yashasvi Moon, email: ymoon@illinois.edu

# %% [markdown]
# **In this notebook we will explore some natural questions that arise from the previous notebooks.**
# 1. Compare the predicted QBS from Random Forests and from KNN. How many are only detected by RF and how many are only detected by KNN? How many are overlapped? Does this make sense given the purity and completeness of both classifiers?
# 2. Which other classifiers can be used for this task? I think Histogram Gradient Booster will be worth trying. Try to apply it using a similar structure from RF and KNN. Other than the Histogram Gradient Booster, what other classifiers can be used? fyi: I primarily stuck with RF and KNN because they were faster for training.
# 3. Compare training times for RF and KNN. Which is faster?
# 4. Astronomy is a vast field. Can you apply these models in your area of interest for research? Which ones?
